# %%
import numpy as np
import pandas as pd
import pyarrow
import random

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows',50)

bookings_file='/Users/c32/Documents/NYCDSA/Project - Data Analysis Python/Datasets/civitatis.csv'

# %%
###Dataset Bookings
bookings = pd.read_csv(bookings_file,low_memory=False, encoding='utf-8')
bookings.shape
# Out:
# (67456, 36)

# %%
bookings.describe(include='all')
# Out:
#         Operaciones      Estado            Id Proveedor ID Res Proveedor  \
# count           0.0       17811  67456.000000     62306            61438
# unique          NaN           2           NaN        16            60083
# top             NaN  modificado           NaN  MarcoBPS            Hecho
# freq            NaN       12863           NaN     13557             1136
# mean            NaN         NaN  45237.849457       NaN              NaN
# std             NaN         NaN  19494.908665       NaN              NaN
# min             NaN         NaN  11479.000000       NaN              NaN
# 25%             NaN         NaN  28354.750000       NaN              NaN
# 50%             NaN         NaN  45240.500000       NaN              NaN
# 75%             NaN         NaN  62126.250000       NaN              NaN
# max             NaN         NaN  78996.000000       NaN              NaN
#
#        ID Res Civitatis Res Relacionada  Nombre Apellidos Cliente  \
# count             67449           44672   67456             67456
# unique            67436           44628    7239             31418
# top             T298129         T298129  Javier          Gonzalez
# freq                  2               3     874               195
# mean                NaN             NaN     NaN               NaN
# std                 NaN             NaN     NaN               NaN
# min                 NaN             NaN     NaN               NaN
# 25%                 NaN             NaN     NaN               NaN
# 50%                 NaN             NaN     NaN               NaN
# 75%                 NaN             NaN     NaN               NaN
# max                 NaN             NaN     NaN               NaN
#
#                Teléfono           Email Cliente       fecha traslado  \
# count             67440                   67056                67456
# unique            38681                   36052                47026
# top     (+34) 699904133  inpetransfer@gmail.com  2023/12/23 17:50:00
# freq                 29                     301                   16
# mean                NaN                     NaN                  NaN
# std                 NaN                     NaN                  NaN
# min                 NaN                     NaN                  NaN
# 25%                 NaN                     NaN                  NaN
# 50%                 NaN                     NaN                  NaN
# 75%                 NaN                     NaN                  NaN
# max                 NaN                     NaN                  NaN
#
#        Hora Traslado  Núm. Pasajeros Tipo vehículo  Tipo desplazamiento  \
# count          67456    67452.000000         67452                67447
# unique           320             NaN            14                    5
# top            15:00             NaN          SUV6  Aeropuerto - Ciudad
# freq            2722             NaN         29002                36850
# mean             NaN        3.873302           NaN                  NaN
# std              NaN        2.164737           NaN                  NaN
# min              NaN        0.000000           NaN                  NaN
# 25%              NaN        2.000000           NaN                  NaN
# 50%              NaN        4.000000           NaN                  NaN
# 75%              NaN        5.000000           NaN                  NaN
# max              NaN       23.000000           NaN                  NaN
#
#                               Ruta  Importe Total      Anticipo  \
# count                        67456   66761.000000  11363.000000
# unique                          45            NaN           NaN
# top     Aeropuerto JFK - Manhattan            NaN           NaN
# freq                         29290            NaN           NaN
# mean                           NaN     134.194551     34.119379
# std                            NaN      44.836267     12.976959
# min                            NaN     -84.500000      0.000000
# 25%                            NaN     106.500000     25.000000
# 50%                            NaN     125.000000     35.000000
# 75%                            NaN     142.500000     35.000000
# max                            NaN     625.000000    245.000000
#
#         Comisión Llevame  Pago en vehículo       Prepago  \
# count       55167.000000      67406.000000  67456.000000
# unique               NaN               NaN           NaN
# top                  NaN               NaN           NaN
# freq                 NaN               NaN           NaN
# mean           11.721958         94.629978      0.818459
# std             3.733126         33.273798      0.385468
# min           -10.000000       -405.000000      0.000000
# 25%            10.000000         75.250000      1.000000
# 50%            10.000000         90.000000      1.000000
# 75%            12.500000        102.750000      1.000000
# max            45.000000        527.750000      1.000000
#
#                         Comentarios Ciudad Origen  \
# count                         12534         40572
# unique                        10090          3328
# top     Conductor que hable español        Madrid
# freq                             23          6781
# mean                            NaN           NaN
# std                             NaN           NaN
# min                             NaN           NaN
# 25%                             NaN           NaN
# 50%                             NaN           NaN
# 75%                             NaN           NaN
# max                             NaN           NaN
#
#                                                 Dirección               Hotel  \
# count                                               67197               28412
# unique                                              23347                9527
# top     Hotel Riu Plaza New York Times Square, West 46...  Hotel Pennsylvania
# freq                                                 2375                 435
# mean                                                  NaN                 NaN
# std                                                   NaN                 NaN
# min                                                   NaN                 NaN
# 25%                                                   NaN                 NaN
# 50%                                                   NaN                 NaN
# 75%                                                   NaN                 NaN
# max                                                   NaN                 NaN
#
#        Núm Vuelo  editar Link confimación Link reserva              Creado  \
# count      66852   67456             1706         1707               67456
# unique     26725       1                1            1               26812
# top       IB6251  Editar     confirmación      reserva  2017/03/29 - 15:07
# freq        1188   67456             1706         1707                 394
# mean         NaN     NaN              NaN          NaN                 NaN
# std          NaN     NaN              NaN          NaN                 NaN
# min          NaN     NaN              NaN          NaN                 NaN
# 25%          NaN     NaN              NaN          NaN                 NaN
# 50%          NaN     NaN              NaN          NaN                 NaN
# 75%          NaN     NaN              NaN          NaN                 NaN
# max          NaN     NaN              NaN          NaN                 NaN
#
#                   Cambiado       Fecha reserva  \
# count                67456               67456
# unique               18495               38070
# top     2023/11/01 - 11:03  2014/04/01 - 15:07
# freq                   856                 132
# mean                   NaN                 NaN
# std                    NaN                 NaN
# min                    NaN                 NaN
# 25%                    NaN                 NaN
# 50%                    NaN                 NaN
# 75%                    NaN                 NaN
# max                    NaN                 NaN
#
#                                   Megarow links         Email Cliente.1  \
# count                                     67456                   67056
# unique                                        1                   36052
# top     abiertatexto E-mail\nver confirmación\n  inpetransfer@gmail.com
# freq                                      67456                     301
# mean                                        NaN                     NaN
# std                                         NaN                     NaN
# min                                         NaN                     NaN
# 25%                                         NaN                     NaN
# 50%                                         NaN                     NaN
# 75%                                         NaN                     NaN
# max                                         NaN                     NaN
#
#         Recordatorio Cliente
# count           67456.000000
# unique                   NaN
# top                      NaN
# freq                     NaN
# mean                0.789730
# std                 0.407504
# min                 0.000000
# 25%                 1.000000
# 50%                 1.000000
# 75%                 1.000000
# max                 1.000000

# %%
#bookings.head()
bookings.loc[random.sample(range(0, bookings.shape[0]), 5)]
# Out:
#            status  supplier booking_id roundtrip_id       name  \
# 10850  modificado      LXNY    T280209          NaN    Camille
# 622           nan    NewDay      61031          NaN    Yannick
# 1991          nan      DH2L     T92120          NaN  Cristina
# 63282         nan  MarcoBPS   T1792537          NaN     Daniel
# 15346         nan      HUGO    T355724      T355721      Angel
#
#               pickup_date pickup_time  number_of_passenger vehicle_type  \
# 10850 2017-10-23 14:20:00       14:20                    2        Sedan
# 622   2014-09-19 17:00:00       17:00                    3         SUV6
# 1991  2015-04-06 15:00:00       15:00                    5         SUV6
# 63282 2023-12-02 19:00:00       19:00                    4         SUV4
# 15346 2018-07-28 13:00:00       13:00                    2        Sedan
#
#                 route_type                       route  total_price  \
# 10850  Ciudad - Aeropuerto  Queens - Aeropuerto Newark        120.0
# 622    Ciudad - Aeropuerto  Manhattan - Aeropuerto JFK        105.0
# 1991   Ciudad - Aeropuerto  Manhattan - Aeropuerto JFK        110.0
# 63282  Aeropuerto - Ciudad  Aeropuerto JFK - Manhattan        130.0
# 15346  Ciudad - Aeropuerto  Manhattan - Aeropuerto JFK         85.0
#
#        total_comission  total_driver  \
# 10850              NaN          95.0
# 622                NaN          75.0
# 1991               NaN          75.0
# 63282             12.5          90.0
# 15346             10.0          60.0
#
#                                            special_notes city_of_departure  \
# 10850                                                NaN               NaN
# 622                                                  NaN          New York
# 1991                                                 NaN          New York
# 63282                                                NaN            Madrid
# 15346  Ciudad de destino Chicago; aeropuerto Chicago ...               NaN
#
#                                                  address  \
# 10850         39-06 30th St, Long Island City, NY 11101,
# 622    250 West 77th Street Upper West Side New York ...
# 1991                               1567 Broadway 10036NY
# 63282  Chelsea Savoy Hotel, West 23rd Street, Nueva Y...
# 15346                       210 East 24th Street , 10010
#
#                                                   hotel  \
# 10850  Home2 Suites by Hilton New York Long Island City
# 622                                   Hotel Belleclaire
# 1991                    Hotel W New York - Times Square
# 63282                                               NaN
# 15346                            The Marcel at Gramercy
#
#                                            flight_number    last_update_date  \
# 10850                                  AIR CANADA AC8495 2018-05-28 14:39:00
# 622                                      Air Europa UX92 2023-11-01 10:45:00
# 1991                             Delta Air Lines DL 6752 2023-11-01 10:47:00
# 63282                                      IBERIA IB6253 2023-12-01 19:00:00
# 15346  AMERICAN AIRLINES 1414 La reserva ha quedado C... 2018-07-28 13:10:00
#
#              booking_date
# 10850 2017-10-13 10:18:00
# 622   2014-08-25 15:08:00
# 1991  2015-03-23 15:12:00
# 63282 2023-11-24 05:04:00
# 15346 2018-07-21 09:32:00

# %%
print(bookings.dtypes)
# Out:
# status                         object
# supplier                       object
# booking_id                     object
# roundtrip_id                   object
# name                           object
# pickup_date            datetime64[ns]
# pickup_time                    object
# number_of_passenger             int64
# vehicle_type                   object
# route_type                     object
# route                          object
# total_price                   float64
# total_comission               float64
# total_driver                  float64
# special_notes                  object
# city_of_departure              object
# address                        object
# hotel                          object
# flight_number                  object
# last_update_date       datetime64[ns]
# booking_date           datetime64[ns]
# dtype: object

# %%
#Decide which columns are being kept
bookings.columns
all=['Operaciones', 'Estado', 'Id', 'Proveedor', 'ID Res Proveedor',
       'ID Res Civitatis', 'Res Relacionada', 'Nombre', 'Apellidos Cliente',
       'Teléfono', 'Email Cliente', 'fecha traslado', 'Hora Traslado',
       'Núm. Pasajeros', 'Tipo vehículo', 'Tipo desplazamiento', 'Ruta',
       'Importe Total', 'Anticipo', 'Comisión Llevame', 'Pago en vehículo',
       'Prepago', 'Comentarios', 'Ciudad Origen', 'Dirección', 'Hotel',
       'Núm Vuelo', 'editar', 'Link confimación', 'Link reserva', 'Creado',
       'Cambiado', 'Fecha reserva', 'Megarow links', 'Email Cliente.1',
       'Recordatorio Cliente']
keeping=['Estado', 'Proveedor', 'ID Res Civitatis', 'Res Relacionada', 'Nombre',
         'fecha traslado', 'Hora Traslado', 'Núm. Pasajeros', 'Tipo vehículo', 
         'Tipo desplazamiento', 'Ruta', 'Importe Total', 'Comisión Llevame', 
         'Pago en vehículo', 'Comentarios', 'Ciudad Origen', 'Dirección', 
         'Hotel', 'Núm Vuelo', 'Cambiado', 'Fecha reserva']
bookings=bookings[keeping]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[319], line 17
#       3 all=['Operaciones', 'Estado', 'Id', 'Proveedor', 'ID Res Proveedor',
#       4        'ID Res Civitatis', 'Res Relacionada', 'Nombre', 'Apellidos Cliente',
#       5        'Teléfono', 'Email Cliente', 'fecha traslado', 'Hora Traslado',
#    (...)
#      10        'Cambiado', 'Fecha reserva', 'Megarow links', 'Email Cliente.1',
#      11        'Recordatorio Cliente']
#      12 keeping=['Estado', 'Proveedor', 'ID Res Civitatis', 'Res Relacionada', 'Nombre',
#      13          'fecha traslado', 'Hora Traslado', 'Núm. Pasajeros', 'Tipo vehículo',
#      14          'Tipo desplazamiento', 'Ruta', 'Importe Total', 'Comisión Llevame',
#      15          'Pago en vehículo', 'Comentarios', 'Ciudad Origen', 'Dirección',
#      16          'Hotel', 'Núm Vuelo', 'Cambiado', 'Fecha reserva']
# ---> 17 bookings=bookings[keeping]
#
# File /usr/local/lib/python3.11/site-packages/pandas/core/frame.py:4096, in DataFrame.__getitem__(self, key)
#    4094     if is_iterator(key):
#    4095         key = list(key)
# -> 4096     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4098 # take() does not accept boolean indexers
#    4099 if getattr(indexer, "dtype", None) == bool:
#
# File /usr/local/lib/python3.11/site-packages/pandas/core/indexes/base.py:6199, in Index._get_indexer_strict(self, key, axis_name)
#    6196 else:
#    6197     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6199 self._raise_if_missing(keyarr, indexer, axis_name)
#    6201 keyarr = self.take(indexer)
#    6202 if isinstance(key, Index):
#    6203     # GH 42790 - Preserve name from an Index
#
# File /usr/local/lib/python3.11/site-packages/pandas/core/indexes/base.py:6248, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6246 if nmissing:
#    6247     if nmissing == len(indexer):
# -> 6248         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6250     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6251     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['Estado', 'Proveedor', 'ID Res Civitatis', 'Res Relacionada', 'Nombre',\n       'fecha traslado', 'Hora Traslado', 'Núm. Pasajeros', 'Tipo vehículo',\n       'Tipo desplazamiento', 'Ruta', 'Importe Total', 'Comisión Llevame',\n       'Pago en vehículo', 'Comentarios', 'Ciudad Origen', 'Dirección',\n       'Hotel', 'Núm Vuelo', 'Cambiado', 'Fecha reserva'],\n      dtype='object')] are in the [columns]"

# %%
#Translate Column Names
bookings.columns
new_names=[str.lower(x) for x in new_names]
new_names=['status', 'supplier', 'booking_id', 'roundtrip_id', 'name', 'pickup_date', 
           'pickup_time', 'number_of_passenger', 'vehicle_type', 'route_type', 'route', 
           'total_price', 'total_comission', 'total_driver', 'special_notes', 'city_of_departure', 
           'address', 'hotel', 'flight_number', 'last_update_date', 'booking_date']
bookings.columns=new_names

# %%
#Convert to Datetimes
#Example of what the source has: 2016/09/01 19:00:00
bookings['pickup_date'] = pd.to_datetime(bookings['pickup_date'])
bookings['last_update_date'] = pd.to_datetime(bookings['last_update_date'])
bookings['booking_date'] = pd.to_datetime(bookings['booking_date'])

# %%
#Remove some personal bookings that will have strange unconventional IDs.
#bookings.sort_values(len(str(bookings['booking_id'])), ascending=False)
#pd.set_option('display.max_rows', 1000)
filter=bookings['booking_id'].astype(str).map(len)>13
sum(filter) #total 18
bookings=bookings[~filter]
bookings.shape
# Out:
# (67438, 21)

# %%
#Remove some cancelled bookings that don't have ID
filter=bookings['booking_id'].isna()
print(sum(filter))
bookings=bookings[~filter]
# Out:
# 7

# %%
#Convert Number of Passengers to Integer
bookings['number_of_passenger']=bookings['number_of_passenger'].fillna(0)
bookings['number_of_passenger']=bookings['number_of_passenger'].astype(int)

# %%
# No String conversion for now.

#Convert to Strings (from object type)
#bookings['status']=bookings['status'].astype(str) 
#=str(bookings['booking_id']).encode('utf8')
#bookings['roundtrip_id']=
#print(bookings['roundtrip_id'].astype('|S')) # which will by default set the length to the max len it encounters
#bookings['name']=
#print(bookings['name'].astype(str))
#.astype('|S')
'''
bookings['vehicle_type']=bookings['vehicle_type'].astype('|S')
bookings['route_type']=bookings['route_type'].astype('|S')
bookings['route']=bookings['route'].astype('|S')
bookings['special_notes']=bookings['special_notes'].astype('|S')
bookings['city_of_departure']=bookings['city_of_departure'].astype('|S')
bookings['address']=bookings['address'].astype('|S')
bookings['hotel']=bookings['hotel'].astype('|S')
bookings['flight_number']=bookings['flight_number'].astype('|S')'''

# %%
#Truncate: Email,'Driver_price', 'commission', 'sale_price'.


#Need to change data types
unique_values_set = set(bookings['supplier'])
#print(unique_values_set)
bookings.supplier.nunique()
bookings['supplier'].unique()
# Out:
# array(['FCLimo', 'NewDay', 'Golden Class Limo', 'PeterLimo', 'DH2L',
#        'Efrain', nan, 'Nestor', 'Camila', 'FRANKLYN', 'LXNY', 'HUGO',
#        'Best Limo', '800S', 'MarcoBPS', 'Patricio', 'Johnny Limo'],
#       dtype=object)

# %%
#Take a look at some expected fixed values

#Need to change data types
unique_values_set = set(bookings['status'])
unique_values_set
# Out:
# {'cancelado', 'modificado', 'nan'}

# %%
#After all the changes, we proceed to save the changes in a file.
import os
outname = 'all_bookings2.0.csv'
outdir = './Datasets'
if not os.path.exists(outdir):
    os.mkdir(outdir)
fullname = os.path.join(outdir, outname)    

bookings.to_csv(fullname, header=True)
print("Saved!")
# Out:
# Saved!
