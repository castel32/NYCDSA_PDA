# %%
import numpy as np
import pandas as pd
import pyarrow
import random

pd.set_option('display.max_columns', 300)
pd.set_option('display.max_rows',50)

bookings_file='./Datasets/Bookings.csv'

# %%
###Dataset Bookings
bookings = pd.read_csv(bookings_file,low_memory=False, encoding='utf-8')
bookings.shape
# Out:
# (67682, 36)

# %%
bookings.describe(include='all')
# Out:
#         Operaciones      Estado            Id Proveedor ID Res Proveedor  \
# count           0.0       17851  67682.000000     62351            61528
# unique          NaN           2           NaN        16            60173
# top             NaN  modificado           NaN  MarcoBPS            Hecho
# freq            NaN       12880           NaN     13578             1136
# mean            NaN         NaN  45350.957064       NaN              NaN
# std             NaN         NaN  19560.189040       NaN              NaN
# min             NaN         NaN  11479.000000       NaN              NaN
# 25%             NaN         NaN  28411.250000       NaN              NaN
# 50%             NaN         NaN  45353.500000       NaN              NaN
# 75%             NaN         NaN  62295.750000       NaN              NaN
# max             NaN         NaN  79224.000000       NaN              NaN
#
#        ID Res Civitatis Res Relacionada  Nombre Apellidos Cliente  \
# count             67675           44862   67682             67682
# unique            67662           44818    7251             31506
# top             T298144         T298170  Javier          Gonzalez
# freq                  2               3     875               195
# mean                NaN             NaN     NaN               NaN
# std                 NaN             NaN     NaN               NaN
# min                 NaN             NaN     NaN               NaN
# 25%                 NaN             NaN     NaN               NaN
# 50%                 NaN             NaN     NaN               NaN
# 75%                 NaN             NaN     NaN               NaN
# max                 NaN             NaN     NaN               NaN
#
#                Teléfono           Email Cliente       fecha traslado  \
# count             67666                   67281                67682
# unique            38795                   36144                47180
# top     (+34) 699904133  inpetransfer@gmail.com  2023/12/23 17:50:00
# freq                 29                     306                   16
# mean                NaN                     NaN                  NaN
# std                 NaN                     NaN                  NaN
# min                 NaN                     NaN                  NaN
# 25%                 NaN                     NaN                  NaN
# 50%                 NaN                     NaN                  NaN
# 75%                 NaN                     NaN                  NaN
# max                 NaN                     NaN                  NaN
#
#        Hora Traslado  Núm. Pasajeros Tipo vehículo  Tipo desplazamiento  \
# count          67682    67678.000000         67678                67673
# unique           320             NaN            14                    5
# top            15:00             NaN          SUV6  Aeropuerto - Ciudad
# freq            2732             NaN         29055                36968
# mean             NaN        3.873519           NaN                  NaN
# std              NaN        2.165635           NaN                  NaN
# min              NaN        0.000000           NaN                  NaN
# 25%              NaN        2.000000           NaN                  NaN
# 50%              NaN        4.000000           NaN                  NaN
# 75%              NaN        5.000000           NaN                  NaN
# max              NaN       23.000000           NaN                  NaN
#
#                               Ruta  Importe Total      Anticipo  \
# count                        67682   66987.000000  11363.000000
# unique                          45            NaN           NaN
# top     Aeropuerto JFK - Manhattan            NaN           NaN
# freq                         29383            NaN           NaN
# mean                           NaN     134.245983     34.119379
# std                            NaN      44.898539     12.976959
# min                            NaN     -84.500000      0.000000
# 25%                            NaN     106.500000     25.000000
# 50%                            NaN     125.000000     35.000000
# 75%                            NaN     142.500000     35.000000
# max                            NaN     625.000000    245.000000
#
#         Comisión Llevame  Pago en vehículo       Prepago  \
# count       55393.000000      67632.000000  67682.000000
# unique               NaN               NaN           NaN
# top                  NaN               NaN           NaN
# freq                 NaN               NaN           NaN
# mean           11.726716         94.661803      0.819066
# std             3.735653         33.310769      0.384967
# min           -10.000000       -405.000000      0.000000
# 25%            10.000000         75.250000      1.000000
# 50%            10.000000         90.000000      1.000000
# 75%            12.500000        102.750000      1.000000
# max            45.000000        527.750000      1.000000
#
#                         Comentarios Ciudad Origen  \
# count                         12564         40694
# unique                        10112          3331
# top     Conductor que hable español        Madrid
# freq                             23          6788
# mean                            NaN           NaN
# std                             NaN           NaN
# min                             NaN           NaN
# 25%                             NaN           NaN
# 50%                             NaN           NaN
# 75%                             NaN           NaN
# max                             NaN           NaN
#
#                                                 Dirección               Hotel  \
# count                                               67423               28418
# unique                                              23364                9528
# top     Hotel Riu Plaza New York Times Square, West 46...  Hotel Pennsylvania
# freq                                                 2395                 435
# mean                                                  NaN                 NaN
# std                                                   NaN                 NaN
# min                                                   NaN                 NaN
# 25%                                                   NaN                 NaN
# 50%                                                   NaN                 NaN
# 75%                                                   NaN                 NaN
# max                                                   NaN                 NaN
#
#        Núm Vuelo  editar Link confimación Link reserva              Creado  \
# count      67077   67682             1706         1707               67682
# unique     26795       1                1            1               26949
# top       IB6251  Editar     confirmación      reserva  2017/03/29 - 15:07
# freq        1192   67682             1706         1707                 394
# mean         NaN     NaN              NaN          NaN                 NaN
# std          NaN     NaN              NaN          NaN                 NaN
# min          NaN     NaN              NaN          NaN                 NaN
# 25%          NaN     NaN              NaN          NaN                 NaN
# 50%          NaN     NaN              NaN          NaN                 NaN
# 75%          NaN     NaN              NaN          NaN                 NaN
# max          NaN     NaN              NaN          NaN                 NaN
#
#                   Cambiado       Fecha reserva  \
# count                67682               67682
# unique               18669               38204
# top     2023/11/01 - 11:03  2014/04/01 - 15:07
# freq                   856                 132
# mean                   NaN                 NaN
# std                    NaN                 NaN
# min                    NaN                 NaN
# 25%                    NaN                 NaN
# 50%                    NaN                 NaN
# 75%                    NaN                 NaN
# max                    NaN                 NaN
#
#                                   Megarow links         Email Cliente.1  \
# count                                     67682                   67281
# unique                                        1                   36144
# top     abiertatexto E-mail\nver confirmación\n  inpetransfer@gmail.com
# freq                                      67682                     306
# mean                                        NaN                     NaN
# std                                         NaN                     NaN
# min                                         NaN                     NaN
# 25%                                         NaN                     NaN
# 50%                                         NaN                     NaN
# 75%                                         NaN                     NaN
# max                                         NaN                     NaN
#
#         Recordatorio Cliente
# count           67682.000000
# unique                   NaN
# top                      NaN
# freq                     NaN
# mean                0.788393
# std                 0.408451
# min                 0.000000
# 25%                 1.000000
# 50%                 1.000000
# 75%                 1.000000
# max                 1.000000

# %%
#bookings.head()
bookings.loc[random.sample(range(0, bookings.shape[0]), 5)]
# Out:
#        Operaciones      Estado     Id  Proveedor ID Res Proveedor  \
# 40699          NaN  modificado  52215       LXNY         T1396521
# 18389          NaN  modificado  29880  Best Limo          T487021
# 18795          NaN         NaN  30286  Best Limo          T506410
# 14967          NaN         NaN  26458       HUGO          T348731
# 65413          NaN         NaN  76953        NaN              NaN
#
#       ID Res Civitatis Res Relacionada   Nombre Apellidos Cliente  \
# 40699         T1396521             NaN  Alfonso      Campo Betran
# 18389          T487021         T487018   Daniel  Permuy Rodriguez
# 18795          T506410         T506413   Esteve         Puigpinos
# 14967          T348731             NaN   Manuel     Medrano Pardo
# 65413         T1831706             NaN  Marcelo             Daneu
#
#                 Teléfono               Email Cliente       fecha traslado  \
# 40699    (+34) 669897306          acbetran@gmail.com  2022/08/29 18:55:00
# 18389      +34 606038384        d.permuy@hotmail.com  2018/12/08 16:30:00
# 18795      +34 676059046  EPUIGPINOSLLURDA@GMAIL.COM  2018/12/26 13:50:00
# 14967      +34 695270565                         NaN  2018/11/22 17:00:00
# 65413  (+55) 82991118235    mercia@mczturismo.com.br  2024/03/22 08:10:00
#
#       Hora Traslado  Núm. Pasajeros Tipo vehículo  Tipo desplazamiento  \
# 40699         18:55             5.0          SUV6  Aeropuerto - Ciudad
# 18389         16:30             2.0         Sedan  Ciudad - Aeropuerto
# 18795         13:50            12.0   Sprinter 12  Aeropuerto - Ciudad
# 14967         17:00             2.0         Sedan  Ciudad - Aeropuerto
# 65413         08:10             1.0         Sedan  Aeropuerto - Ciudad
#
#                                 Ruta  Importe Total  Anticipo  \
# 40699     Aeropuerto JFK - Manhattan          142.5       NaN
# 18389      Brooklyn - Aeropuerto JFK           85.0       NaN
# 18795  Aeropuerto Newark - Manhattan          300.0       NaN
# 14967     Manhattan - Aeropuerto JFK           85.0       NaN
# 65413  Aeropuerto Newark - Manhattan          138.0       NaN
#
#        Comisión Llevame  Pago en vehículo  Prepago Comentarios Ciudad Origen  \
# 40699               9.5            102.75        1         NaN        Madrid
# 18389              10.0             60.00        1         NaN           NaN
# 18795              20.0            200.00        1         NaN     BARCELONA
# 14967              10.0             60.00        1         NaN           NaN
# 65413              10.0             97.25        1         NaN     GUARULHOD
#
#                                                Dirección  \
# 40699  TRYP by Wyndham New York City Times Square Sou...
# 18389           247 metropolitan ave, brooklyn, NY 11211
# 18795                    777 8th Ave, New York, NY 10036
# 14967                                     866 3rd Avenue
# 65413  Element New York Times Square West, Between 8t...
#
#                                                Hotel    Núm Vuelo  editar  \
# 40699                                            NaN       IB6253  Editar
# 18389                                   Pod brooklyn          NaN  Editar
# 18795                                   ROW NY HOTEL       UA 121  Editar
# 14967  Courtyard by marriott new york city manhattan  IBERIA 6252  Editar
# 65413                                            NaN       UA 148  Editar
#
#       Link confimación Link reserva              Creado            Cambiado  \
# 40699              NaN          NaN  2022/08/27 - 17:00  2023/11/01 - 11:52
# 18389              NaN          NaN  2018/11/25 - 17:00  2018/12/08 - 16:12
# 18795              NaN          NaN  2018/12/12 - 15:00  2018/12/26 - 15:30
# 14967              NaN          NaN  2018/07/04 - 16:00  2018/11/22 - 18:51
# 65413              NaN          NaN  2024/01/03 - 14:59  2024/01/03 - 15:00
#
#             Fecha reserva                            Megarow links  \
# 40699  2022/08/27 - 17:47  abiertatexto E-mail\nver confirmación\n
# 18389  2018/11/25 - 17:15  abiertatexto E-mail\nver confirmación\n
# 18795  2018/12/12 - 15:11  abiertatexto E-mail\nver confirmación\n
# 14967  2018/07/04 - 16:13  abiertatexto E-mail\nver confirmación\n
# 65413  2024/01/03 - 15:59  abiertatexto E-mail\nver confirmación\n
#
#                   Email Cliente.1  Recordatorio Cliente
# 40699          acbetran@gmail.com                     1
# 18389        d.permuy@hotmail.com                     1
# 18795  EPUIGPINOSLLURDA@GMAIL.COM                     1
# 14967                         NaN                     1
# 65413    mercia@mczturismo.com.br                     0

# %%
print(bookings.dtypes)
# Out:
# Operaciones             float64
# Estado                   object
# Id                        int64
# Proveedor                object
# ID Res Proveedor         object
# ID Res Civitatis         object
# Res Relacionada          object
# Nombre                   object
# Apellidos Cliente        object
# Teléfono                 object
# Email Cliente            object
# fecha traslado           object
# Hora Traslado            object
# Núm. Pasajeros          float64
# Tipo vehículo            object
# Tipo desplazamiento      object
# Ruta                     object
# Importe Total           float64
# Anticipo                float64
# Comisión Llevame        float64
# Pago en vehículo        float64
# Prepago                   int64
# Comentarios              object
# Ciudad Origen            object
# Dirección                object
# Hotel                    object
# Núm Vuelo                object
# editar                   object
# Link confimación         object
# Link reserva             object
# Creado                   object
# Cambiado                 object
# Fecha reserva            object
# Megarow links            object
# Email Cliente.1          object
# Recordatorio Cliente      int64
# dtype: object

# %%
#Decide which columns are being kept
print(bookings.columns)
all=['Operaciones', 'Estado', 'Id', 'Proveedor', 'ID Res Proveedor',
       'ID Res Civitatis', 'Res Relacionada', 'Nombre', 'Apellidos Cliente',
       'Teléfono', 'Email Cliente', 'fecha traslado', 'Hora Traslado',
       'Núm. Pasajeros', 'Tipo vehículo', 'Tipo desplazamiento', 'Ruta',
       'Importe Total', 'Anticipo', 'Comisión Llevame', 'Pago en vehículo',
       'Prepago', 'Comentarios', 'Ciudad Origen', 'Dirección', 'Hotel',
       'Núm Vuelo', 'editar', 'Link confimación', 'Link reserva', 'Creado',
       'Cambiado', 'Fecha reserva', 'Megarow links', 'Email Cliente.1',
       'Recordatorio Cliente']
keeping=['Estado', 'Proveedor', 'ID Res Civitatis', 'Res Relacionada', 'Nombre',
         'fecha traslado', 'Hora Traslado', 'Núm. Pasajeros', 'Tipo vehículo', 
         'Tipo desplazamiento', 'Ruta', 'Importe Total', 'Comisión Llevame', 
         'Pago en vehículo', 'Comentarios', 'Ciudad Origen', 'Dirección', 
         'Hotel', 'Núm Vuelo', 'Cambiado', 'Fecha reserva']
bookings=bookings[keeping]
# Out:
# Index(['Operaciones', 'Estado', 'Id', 'Proveedor', 'ID Res Proveedor',
#        'ID Res Civitatis', 'Res Relacionada', 'Nombre', 'Apellidos Cliente',
#        'Teléfono', 'Email Cliente', 'fecha traslado', 'Hora Traslado',
#        'Núm. Pasajeros', 'Tipo vehículo', 'Tipo desplazamiento', 'Ruta',
#        'Importe Total', 'Anticipo', 'Comisión Llevame', 'Pago en vehículo',
#        'Prepago', 'Comentarios', 'Ciudad Origen', 'Dirección', 'Hotel',
#        'Núm Vuelo', 'editar', 'Link confimación', 'Link reserva', 'Creado',
#        'Cambiado', 'Fecha reserva', 'Megarow links', 'Email Cliente.1',
#        'Recordatorio Cliente'],
#       dtype='object')

# %%
bookings.columns
# Out:
# Index(['Estado', 'Proveedor', 'ID Res Civitatis', 'Res Relacionada', 'Nombre',
#        'fecha traslado', 'Hora Traslado', 'Núm. Pasajeros', 'Tipo vehículo',
#        'Tipo desplazamiento', 'Ruta', 'Importe Total', 'Comisión Llevame',
#        'Pago en vehículo', 'Comentarios', 'Ciudad Origen', 'Dirección',
#        'Hotel', 'Núm Vuelo', 'Cambiado', 'Fecha reserva'],
#       dtype='object')

# %%
#Translate Column Names
new_names = bookings.columns
new_names=[str.lower(x) for x in new_names]
new_names=['status', 'supplier', 'booking_id', 'roundtrip_id', 'name', 'pickup_date', 
           'pickup_time', 'number_of_passenger', 'vehicle_type', 'route_type', 'route', 
           'total_price', 'total_comission', 'total_driver', 'special_notes', 'city_of_departure', 
           'address', 'hotel', 'flight_number', 'last_update_date', 'booking_date']
bookings.columns=new_names

# %%
#Convert to Datetimes
#Example of what the source has: 2016/09/01 19:00:00
bookings['pickup_date'] = pd.to_datetime(bookings['pickup_date'])
bookings['last_update_date'] = pd.to_datetime(bookings['last_update_date'])
bookings['booking_date'] = pd.to_datetime(bookings['booking_date'])

# %%
#Remove some personal bookings that will have strange unconventional IDs.
#bookings.sort_values(len(str(bookings['booking_id'])), ascending=False)
#pd.set_option('display.max_rows', 1000)
filter=bookings['booking_id'].astype(str).map(len)>13
sum(filter) #total 18
bookings=bookings[~filter]
bookings.shape
# Out:
# (67664, 21)

# %%
#Remove some cancelled bookings that don't have ID
filter=bookings['booking_id'].isna()
print(sum(filter))
bookings=bookings[~filter]
# Out:
# 7

# %%
#Convert Number of Passengers to Integer
bookings['number_of_passenger']=bookings['number_of_passenger'].fillna(0)
bookings['number_of_passenger']=bookings['number_of_passenger'].astype(int)

# %%
# No String conversion for now.

#Convert to Strings (from object type)
#bookings['status']=bookings['status'].astype(str) 
#=str(bookings['booking_id']).encode('utf8')
#bookings['roundtrip_id']=
#print(bookings['roundtrip_id'].astype('|S')) # which will by default set the length to the max len it encounters
#bookings['name']=
#print(bookings['name'].astype(str))
#.astype('|S')
'''
bookings['vehicle_type']=bookings['vehicle_type'].astype('|S')
bookings['route_type']=bookings['route_type'].astype('|S')
bookings['route']=bookings['route'].astype('|S')
bookings['special_notes']=bookings['special_notes'].astype('|S')
bookings['city_of_departure']=bookings['city_of_departure'].astype('|S')
bookings['address']=bookings['address'].astype('|S')
bookings['hotel']=bookings['hotel'].astype('|S')
bookings['flight_number']=bookings['flight_number'].astype('|S')'''
# Out:
# "\nbookings['vehicle_type']=bookings['vehicle_type'].astype('|S')\nbookings['route_type']=bookings['route_type'].astype('|S')\nbookings['route']=bookings['route'].astype('|S')\nbookings['special_notes']=bookings['special_notes'].astype('|S')\nbookings['city_of_departure']=bookings['city_of_departure'].astype('|S')\nbookings['address']=bookings['address'].astype('|S')\nbookings['hotel']=bookings['hotel'].astype('|S')\nbookings['flight_number']=bookings['flight_number'].astype('|S')"

# %%
#Truncate: Email,'Driver_price', 'commission', 'sale_price'.


#Need to change data types
unique_values_set = set(bookings['supplier'])
#print(unique_values_set)
bookings.supplier.nunique()
bookings['supplier'].unique()
# Out:
# array(['FCLimo', 'NewDay', 'Golden Class Limo', 'PeterLimo', 'DH2L',
#        'Efrain', nan, 'Nestor', 'Camila', 'FRANKLYN', 'LXNY', 'HUGO',
#        'Best Limo', '800S', 'MarcoBPS', 'Patricio', 'Johnny Limo'],
#       dtype=object)

# %%
#Take a look at some expected fixed values

#Need to change data types
unique_values_set = set(bookings['status'])
unique_values_set
# Out:
# {'cancelado', 'modificado', nan}

# %%
#After all the changes, we proceed to save the changes in a file.
import os
outname = 'all_bookings2.0.csv'
outdir = './Datasets'
if not os.path.exists(outdir):
    os.mkdir(outdir)
fullname = os.path.join(outdir, outname)    

bookings.to_csv(fullname, header=True, index=False)
print("Saved!")
# Out:
# Saved!
